# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/main/C4/W3/ungraded_labs/C4_W3_Lab_2_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Using a multi-layer LSTM for forecasting
#
# In this lab, you will use the same RNN architecure in the first lab but will instead stack [LSTM](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTM) layers instead of `SimpleRNN`.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2024-05-02 09:00:24.669092: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Utilities

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    
    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

def trend(time, slope=0):
    """
    Generates synthetic data that follows a straight line given a slope value.

    Args:
      time (array of int) - contains the time steps
      slope (float) - determines the direction and steepness of the line

    Returns:
      series (array of float) - measurements that follow a straight line
    """

    # Compute the linear series given the slope
    series = slope * time

    return series

def seasonal_pattern(season_time):
    """
    Just an arbitrary pattern, you can change it if you wish
    
    Args:
      season_time (array of float) - contains the measurements per time step

    Returns:
      data_pattern (array of float) -  contains revised measurement values according 
                                  to the defined pattern
    """

    # Generate the values using an arbitrary pattern
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))
    
    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    """
    Repeats the same pattern at each period

    Args:
      time (array of int) - contains the time steps
      period (int) - number of time steps before the pattern repeats
      amplitude (int) - peak measured value in a period
      phase (int) - number of time steps to shift the measured values

    Returns:
      data_pattern (array of float) - seasonal data scaled by the defined amplitude
    """
    
    # Define the measured values per period
    season_time = ((time + phase) % period) / period

    # Generates the seasonal data scaled by the defined amplitude
    data_pattern = amplitude * seasonal_pattern(season_time)

    return data_pattern

def noise(time, noise_level=1, seed=None):
    """Generates a normally distributed noisy signal

    Args:
      time (array of int) - contains the time steps
      noise_level (float) - scaling factor for the generated signal
      seed (int) - number generator seed for repeatability

    Returns:
      noise (array of float) - the noisy signal
    """

    # Initialize the random number generator
    rnd = np.random.RandomState(seed)

    # Generate a random number for each time step and scale by the noise level
    noise = rnd.randn(len(time)) * noise_level
    
    return noise

# %% [markdown]
# ## Generate the Synthetic Data

# %%
# Parameters
time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)

# Update with noise
series += noise(time, noise_level, seed=42)

# Plot the results
plot_series(time, series)

# %% [markdown]
# ## Split the Dataset

# %%
# Define the split time
split_time = 1000

# Get the train set 
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# ## Prepare Features and Labels

# %%
# Parameters
window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """
  
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels 
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    return dataset

# %%
# Generate the dataset windows
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Build the Model
#
# As mentioned, you will swap `SimpleRNN` for `LSTM` in this lab. It is also set as bidirectional below but feel free to revise later and see what results you get. LSTMs are much more complex in their internal architecture than simpleRNNs. It implements a cell state that allows it to remember sequences better than simple implementations. This added complexity results in a bigger set of parameters to train and you'll see that when you print the model summary below.

# %%
# Build the Model
model_tune = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[window_size]),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Print the model summary
model_tune.summary()
# Out:
# 2024-05-02 09:00:54.573509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:00:54.575688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:00:54.576995: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:00:54.744652: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:00:54.801034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:00:54.803036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:00:54.804209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:00:55.027076: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:00:55.028741: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:00:55.030693: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:00:55.186365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, 20, 1)             0
#
#  bidirectional (Bidirectiona  (None, 20, 64)           8704
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 64)               24832
#  nal)
#
#  dense (Dense)               (None, 1)                 65
#
#  lambda_1 (Lambda)           (None, 1)                 0
#
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________
# 2024-05-02 09:00:55.238577: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:00:55.240407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:00:55.241951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %% [markdown]
# ## Tune the Learning Rate
#
# As usual, you will pick a learning rate by running the tuning code below.

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune.fit(dataset, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 2024-05-02 09:01:03.043659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [1000]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-02 09:01:03.044097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [1000]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-02 09:01:03.306789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:01:03.308661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:01:03.310560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:01:03.487369: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:01:03.554354: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:01:03.556827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:01:03.558319: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:01:03.804595: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:01:03.806579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:01:03.807892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:01:03.973251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:01:04.034670: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:01:04.036476: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:01:04.038094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:01:04.671387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:01:05.168856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:01:05.729050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:01:05.731195: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:01:05.733314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:01:05.903923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:01:05.967034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:01:05.968865: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:01:05.970188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:01:06.212091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:01:06.214645: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:01:06.216206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:01:06.389746: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:01:06.448344: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:01:06.452415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:01:06.454203: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:01:07.009746: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:01:07.518789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 31/31 [==============================] - 7s 32ms/step - loss: 58.6143 - lr: 1.0000e-08
# Epoch 2/100
# 31/31 [==============================] - 1s 16ms/step - loss: 57.7268 - lr: 1.1220e-08
# Epoch 3/100
# 31/31 [==============================] - 1s 16ms/step - loss: 56.7257 - lr: 1.2589e-08
# Epoch 4/100
# 31/31 [==============================] - 1s 16ms/step - loss: 55.6474 - lr: 1.4125e-08
# Epoch 5/100
# 31/31 [==============================] - 1s 16ms/step - loss: 54.4430 - lr: 1.5849e-08
# Epoch 6/100
# 31/31 [==============================] - 1s 16ms/step - loss: 53.0464 - lr: 1.7783e-08
# Epoch 7/100
# 31/31 [==============================] - 1s 20ms/step - loss: 51.3526 - lr: 1.9953e-08
# Epoch 8/100
# 31/31 [==============================] - 1s 17ms/step - loss: 49.1286 - lr: 2.2387e-08
# Epoch 9/100
# 31/31 [==============================] - 1s 16ms/step - loss: 45.9769 - lr: 2.5119e-08
# Epoch 10/100
# 31/31 [==============================] - 1s 18ms/step - loss: 41.6762 - lr: 2.8184e-08
# Epoch 11/100
# 31/31 [==============================] - 1s 17ms/step - loss: 37.1820 - lr: 3.1623e-08
# Epoch 12/100
# 31/31 [==============================] - 1s 18ms/step - loss: 33.5389 - lr: 3.5481e-08
# Epoch 13/100
# 31/31 [==============================] - 1s 18ms/step - loss: 30.4704 - lr: 3.9811e-08
# Epoch 14/100
# 31/31 [==============================] - 1s 19ms/step - loss: 27.6189 - lr: 4.4668e-08
# Epoch 15/100
# 31/31 [==============================] - 1s 17ms/step - loss: 24.7858 - lr: 5.0119e-08
# Epoch 16/100
# 31/31 [==============================] - 1s 17ms/step - loss: 22.1200 - lr: 5.6234e-08
# Epoch 17/100
# 31/31 [==============================] - 1s 16ms/step - loss: 19.6281 - lr: 6.3096e-08
# Epoch 18/100
# 31/31 [==============================] - 1s 16ms/step - loss: 17.3743 - lr: 7.0795e-08
# Epoch 19/100
# 31/31 [==============================] - 1s 16ms/step - loss: 15.8246 - lr: 7.9433e-08
# Epoch 20/100
# 31/31 [==============================] - 1s 16ms/step - loss: 15.0345 - lr: 8.9125e-08
# Epoch 21/100
# 31/31 [==============================] - 1s 17ms/step - loss: 14.5806 - lr: 1.0000e-07
# Epoch 22/100
# 31/31 [==============================] - 1s 16ms/step - loss: 14.1862 - lr: 1.1220e-07
# Epoch 23/100
# 31/31 [==============================] - 1s 16ms/step - loss: 13.7712 - lr: 1.2589e-07
# Epoch 24/100
# 31/31 [==============================] - 1s 16ms/step - loss: 13.3121 - lr: 1.4125e-07
# Epoch 25/100
# 31/31 [==============================] - 1s 16ms/step - loss: 12.8454 - lr: 1.5849e-07
# Epoch 26/100
# 31/31 [==============================] - 1s 16ms/step - loss: 12.3732 - lr: 1.7783e-07
# Epoch 27/100
# 31/31 [==============================] - 1s 16ms/step - loss: 11.8723 - lr: 1.9953e-07
# Epoch 28/100
# 31/31 [==============================] - 1s 16ms/step - loss: 11.3380 - lr: 2.2387e-07
# Epoch 29/100
# 31/31 [==============================] - 1s 16ms/step - loss: 10.7648 - lr: 2.5119e-07
# Epoch 30/100
# 31/31 [==============================] - 1s 17ms/step - loss: 10.0934 - lr: 2.8184e-07
# Epoch 31/100
# 31/31 [==============================] - 1s 19ms/step - loss: 9.3907 - lr: 3.1623e-07
# Epoch 32/100
# 31/31 [==============================] - 1s 16ms/step - loss: 8.7470 - lr: 3.5481e-07
# Epoch 33/100
# 31/31 [==============================] - 1s 18ms/step - loss: 8.3533 - lr: 3.9811e-07
# Epoch 34/100
# 31/31 [==============================] - 1s 17ms/step - loss: 8.3775 - lr: 4.4668e-07
# Epoch 35/100
# 31/31 [==============================] - 1s 16ms/step - loss: 7.7421 - lr: 5.0119e-07
# Epoch 36/100
# 31/31 [==============================] - 1s 16ms/step - loss: 7.3237 - lr: 5.6234e-07
# Epoch 37/100
# 31/31 [==============================] - 1s 18ms/step - loss: 7.2231 - lr: 6.3096e-07
# Epoch 38/100
# 31/31 [==============================] - 1s 17ms/step - loss: 7.1674 - lr: 7.0795e-07
# Epoch 39/100
# 31/31 [==============================] - 1s 17ms/step - loss: 7.0334 - lr: 7.9433e-07
# Epoch 40/100
# 31/31 [==============================] - 1s 23ms/step - loss: 6.9487 - lr: 8.9125e-07
# Epoch 41/100
# 31/31 [==============================] - 1s 18ms/step - loss: 7.2369 - lr: 1.0000e-06
# Epoch 42/100
# 31/31 [==============================] - 1s 17ms/step - loss: 6.9096 - lr: 1.1220e-06
# Epoch 43/100
# 31/31 [==============================] - 1s 17ms/step - loss: 6.6384 - lr: 1.2589e-06
# Epoch 44/100
# 31/31 [==============================] - 1s 16ms/step - loss: 6.4373 - lr: 1.4125e-06
# Epoch 45/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.4820 - lr: 1.5849e-06
# Epoch 46/100
# 31/31 [==============================] - 1s 17ms/step - loss: 6.7222 - lr: 1.7783e-06
# Epoch 47/100
# 31/31 [==============================] - 1s 17ms/step - loss: 6.3039 - lr: 1.9953e-06
# Epoch 48/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.3942 - lr: 2.2387e-06
# Epoch 49/100
# 31/31 [==============================] - 1s 21ms/step - loss: 6.0879 - lr: 2.5119e-06
# Epoch 50/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.9479 - lr: 2.8184e-06
# Epoch 51/100
# 31/31 [==============================] - 1s 17ms/step - loss: 6.0297 - lr: 3.1623e-06
# Epoch 52/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.8813 - lr: 3.5481e-06
# Epoch 53/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.7786 - lr: 3.9811e-06
# Epoch 54/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.0854 - lr: 4.4668e-06
# Epoch 55/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.7849 - lr: 5.0119e-06
# Epoch 56/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.4567 - lr: 5.6234e-06
# Epoch 57/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.4066 - lr: 6.3096e-06
# Epoch 58/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.6593 - lr: 7.0795e-06
# Epoch 59/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.5810 - lr: 7.9433e-06
# Epoch 60/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.3650 - lr: 8.9125e-06
# Epoch 61/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.7788 - lr: 1.0000e-05
# Epoch 62/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.3626 - lr: 1.1220e-05
# Epoch 63/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.3226 - lr: 1.2589e-05
# Epoch 64/100
# 31/31 [==============================] - 1s 17ms/step - loss: 6.2064 - lr: 1.4125e-05
# Epoch 65/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.1414 - lr: 1.5849e-05
# Epoch 66/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.5786 - lr: 1.7783e-05
# Epoch 67/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.0829 - lr: 1.9953e-05
# Epoch 68/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.2752 - lr: 2.2387e-05
# Epoch 69/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.8959 - lr: 2.5119e-05
# Epoch 70/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.3963 - lr: 2.8184e-05
# Epoch 71/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.0952 - lr: 3.1623e-05
# Epoch 72/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.1107 - lr: 3.5481e-05
# Epoch 73/100
# 31/31 [==============================] - 1s 17ms/step - loss: 7.1255 - lr: 3.9811e-05
# Epoch 74/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.6366 - lr: 4.4668e-05
# Epoch 75/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.2711 - lr: 5.0119e-05
# Epoch 76/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.9272 - lr: 5.6234e-05
# Epoch 77/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.7521 - lr: 6.3096e-05
# Epoch 78/100
# 31/31 [==============================] - 1s 16ms/step - loss: 7.3769 - lr: 7.0795e-05
# Epoch 79/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.1405 - lr: 7.9433e-05
# Epoch 80/100
# 31/31 [==============================] - 1s 16ms/step - loss: 8.0143 - lr: 8.9125e-05
# Epoch 81/100
# 31/31 [==============================] - 1s 17ms/step - loss: 6.5475 - lr: 1.0000e-04
# Epoch 82/100
# 31/31 [==============================] - 1s 17ms/step - loss: 6.3332 - lr: 1.1220e-04
# Epoch 83/100
# 31/31 [==============================] - 1s 16ms/step - loss: 6.0895 - lr: 1.2589e-04
# Epoch 84/100
# 31/31 [==============================] - 1s 17ms/step - loss: 5.9935 - lr: 1.4125e-04
# Epoch 85/100
# 31/31 [==============================] - 1s 16ms/step - loss: 7.8495 - lr: 1.5849e-04
# Epoch 86/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.3678 - lr: 1.7783e-04
# Epoch 87/100
# 31/31 [==============================] - 1s 16ms/step - loss: 9.2022 - lr: 1.9953e-04
# Epoch 88/100
# 31/31 [==============================] - 1s 16ms/step - loss: 8.8518 - lr: 2.2387e-04
# Epoch 89/100
# 31/31 [==============================] - 1s 16ms/step - loss: 6.4142 - lr: 2.5119e-04
# Epoch 90/100
# 31/31 [==============================] - 1s 16ms/step - loss: 7.6421 - lr: 2.8184e-04
# Epoch 91/100
# 31/31 [==============================] - 1s 17ms/step - loss: 7.8419 - lr: 3.1623e-04
# Epoch 92/100
# 31/31 [==============================] - 1s 18ms/step - loss: 10.0834 - lr: 3.5481e-04
# Epoch 93/100
# 31/31 [==============================] - 1s 17ms/step - loss: 9.4987 - lr: 3.9811e-04
# Epoch 94/100
# 31/31 [==============================] - 1s 16ms/step - loss: 11.2816 - lr: 4.4668e-04
# Epoch 95/100
# 31/31 [==============================] - 1s 17ms/step - loss: 10.6482 - lr: 5.0119e-04
# Epoch 96/100
# 31/31 [==============================] - 1s 16ms/step - loss: 14.4200 - lr: 5.6234e-04
# Epoch 97/100
# 31/31 [==============================] - 1s 16ms/step - loss: 13.0770 - lr: 6.3096e-04
# Epoch 98/100
# 31/31 [==============================] - 1s 17ms/step - loss: 10.3194 - lr: 7.0795e-04
# Epoch 99/100
# 31/31 [==============================] - 1s 16ms/step - loss: 19.8285 - lr: 7.9433e-04
# Epoch 100/100
# 31/31 [==============================] - 1s 18ms/step - loss: 13.3498 - lr: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 30])
# Out:
# (1e-08, 0.001, 0.0, 30.0)

# %% [markdown]
# ## Train the Model
#
# You can then proceed to train the model with your chosen learning rate.
#
# *Tip: When experimenting and you find yourself running different iterations of a model, you may want to use the [`clear_session()`](https://www.tensorflow.org/api_docs/python/tf/keras/backend/clear_session) method to declutter memory used by Keras. This is added in the first line below.*

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
   tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Set the learning rate
learning_rate = 2e-6

# Set the optimizer 
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(dataset,epochs=100)
# Out:
# 2024-05-02 09:06:44.086145: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:44.087632: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:44.089229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:44.256148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:44.314527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:44.316415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:44.317747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:44.562703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:44.564371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:44.565896: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:44.713507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:44.763203: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:44.764603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# Epoch 1/100
# 2024-05-02 09:06:44.766853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:45.029581: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:45.032112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:45.033430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:45.206252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:45.291183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:45.294807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:45.297308: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:45.592667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:45.595714: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:45.597970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:45.763844: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:45.822632: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:45.825265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:45.827940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:46.405587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:46.925609: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:47.323998: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:47.327318: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:47.328999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:47.508993: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:47.826544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:47.828782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:47.830355: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:48.096340: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:48.098299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:48.099653: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:48.275440: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:48.338273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:06:48.341182: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:06:48.343103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:06:48.933819: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:06:49.485322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 31/31 [==============================] - 7s 17ms/step - loss: 54.3405 - mae: 54.8375
# Epoch 2/100
# 31/31 [==============================] - 1s 16ms/step - loss: 12.6977 - mae: 13.1882
# Epoch 3/100
# 31/31 [==============================] - 1s 16ms/step - loss: 9.2465 - mae: 9.7354
# Epoch 4/100
# 31/31 [==============================] - 1s 16ms/step - loss: 7.6567 - mae: 8.1419
# Epoch 5/100
# 31/31 [==============================] - 1s 16ms/step - loss: 6.6271 - mae: 7.1115
# Epoch 6/100
# 31/31 [==============================] - 1s 16ms/step - loss: 6.2528 - mae: 6.7378
# Epoch 7/100
# 31/31 [==============================] - 1s 16ms/step - loss: 6.0793 - mae: 6.5625
# Epoch 8/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.9118 - mae: 6.3931
# Epoch 9/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.8139 - mae: 6.2938
# Epoch 10/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.6135 - mae: 6.0906
# Epoch 11/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.5350 - mae: 6.0097
# Epoch 12/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.3766 - mae: 5.8555
# Epoch 13/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.2707 - mae: 5.7458
# Epoch 14/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.2721 - mae: 5.7497
# Epoch 15/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.2399 - mae: 5.7154
# Epoch 16/100
# 31/31 [==============================] - 1s 16ms/step - loss: 5.0803 - mae: 5.5555
# Epoch 17/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.0424 - mae: 5.5172
# Epoch 18/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.0859 - mae: 5.5625
# Epoch 19/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.9717 - mae: 5.4479
# Epoch 20/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.8960 - mae: 5.3744
# Epoch 21/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.0118 - mae: 5.4881
# Epoch 22/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.9648 - mae: 5.4405
# Epoch 23/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.8623 - mae: 5.3387
# Epoch 24/100
# 31/31 [==============================] - 1s 19ms/step - loss: 4.7911 - mae: 5.2671
# Epoch 25/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.8921 - mae: 5.3693
# Epoch 26/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.8880 - mae: 5.3616
# Epoch 27/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.7474 - mae: 5.2229
# Epoch 28/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.7305 - mae: 5.2051
# Epoch 29/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.7260 - mae: 5.2006
# Epoch 30/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.7112 - mae: 5.1896
# Epoch 31/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6869 - mae: 5.1608
# Epoch 32/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.7167 - mae: 5.1915
# Epoch 33/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.6592 - mae: 5.1381
# Epoch 34/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6522 - mae: 5.1266
# Epoch 35/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.8211 - mae: 5.2971
# Epoch 36/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6421 - mae: 5.1227
# Epoch 37/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.6417 - mae: 5.1213
# Epoch 38/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6877 - mae: 5.1592
# Epoch 39/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6267 - mae: 5.1037
# Epoch 40/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6306 - mae: 5.1078
# Epoch 41/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6838 - mae: 5.1586
# Epoch 42/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5941 - mae: 5.0697
# Epoch 43/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.5750 - mae: 5.0542
# Epoch 44/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5991 - mae: 5.0803
# Epoch 45/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5659 - mae: 5.0434
# Epoch 46/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5285 - mae: 5.0038
# Epoch 47/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5457 - mae: 5.0234
# Epoch 48/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6096 - mae: 5.0878
# Epoch 49/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5639 - mae: 5.0404
# Epoch 50/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.5461 - mae: 5.0214
# Epoch 51/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5501 - mae: 5.0274
# Epoch 52/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5297 - mae: 5.0081
# Epoch 53/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5016 - mae: 4.9798
# Epoch 54/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6508 - mae: 5.1284
# Epoch 55/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6025 - mae: 5.0755
# Epoch 56/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5390 - mae: 5.0145
# Epoch 57/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6781 - mae: 5.1593
# Epoch 58/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6836 - mae: 5.1605
# Epoch 59/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5128 - mae: 4.9955
# Epoch 60/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.6628 - mae: 5.1378
# Epoch 61/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.6036 - mae: 5.0755
# Epoch 62/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5255 - mae: 5.0023
# Epoch 63/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6037 - mae: 5.0780
# Epoch 64/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5449 - mae: 5.0202
# Epoch 65/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.5908 - mae: 5.0685
# Epoch 66/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4927 - mae: 4.9671
# Epoch 67/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4735 - mae: 4.9502
# Epoch 68/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4845 - mae: 4.9636
# Epoch 69/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4542 - mae: 4.9322
# Epoch 70/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4797 - mae: 4.9575
# Epoch 71/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4906 - mae: 4.9658
# Epoch 72/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4512 - mae: 4.9251
# Epoch 73/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.5030 - mae: 4.9817
# Epoch 74/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4844 - mae: 4.9617
# Epoch 75/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4512 - mae: 4.9293
# Epoch 76/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5190 - mae: 4.9959
# Epoch 77/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5432 - mae: 5.0225
# Epoch 78/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5153 - mae: 4.9927
# Epoch 79/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4686 - mae: 4.9462
# Epoch 80/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4391 - mae: 4.9165
# Epoch 81/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4019 - mae: 4.8743
# Epoch 82/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4338 - mae: 4.9078
# Epoch 83/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.4794 - mae: 4.9538
# Epoch 84/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6337 - mae: 5.1091
# Epoch 85/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.5846 - mae: 5.0617
# Epoch 86/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5046 - mae: 4.9832
# Epoch 87/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4328 - mae: 4.9098
# Epoch 88/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5451 - mae: 5.0175
# Epoch 89/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4089 - mae: 4.8827
# Epoch 90/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4601 - mae: 4.9363
# Epoch 91/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6140 - mae: 5.0927
# Epoch 92/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4928 - mae: 4.9678
# Epoch 93/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4460 - mae: 4.9218
# Epoch 94/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4072 - mae: 4.8805
# Epoch 95/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4274 - mae: 4.9064
# Epoch 96/100
# 31/31 [==============================] - 1s 17ms/step - loss: 4.4458 - mae: 4.9253
# Epoch 97/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.6618 - mae: 5.1367
# Epoch 98/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.5455 - mae: 5.0256
# Epoch 99/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4267 - mae: 4.9000
# Epoch 100/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.4632 - mae: 4.9395

# %% [markdown]
# ## Model Prediction
#
# You will then generate batches of windows to generate predictions that align with the validation set.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    # Get predictions on the entire dataset
    forecast = model.predict(dataset)
    
    return forecast

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2024-05-02 09:08:20.297220: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-02 09:08:20.297618: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [480]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-02 09:08:20.540463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:08:20.542788: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:08:20.544098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:08:20.715713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:08:20.775445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:08:20.777229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:08:20.778453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:08:20.988572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:08:20.990798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:08:20.992805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:08:21.200114: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:08:21.274199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:08:21.275627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:08:21.276871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 15/15 [==============================] - 2s 8ms/step

# %% [markdown]
# You can then generate the metrics to evaluate the model's performance.

# %%
# Compute the MSE and MAE
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 81.45386
# 6.5579505

# %% [markdown]
# ## Wrap Up
#
# This concludes this short exercise on using LSTMs for time series forecasting. Next week, you will build upon this and add convolutions. Then, you will start to move away from synthetic data and use real-world datasets. See you there!

# %% [markdown]
# ## Optional: Including a Validation Set while Training
#
# Back in the first course of this specialization, you saw how you can also monitor the performance of your model against a validation set while training. You can also do that for this lab.
#
# First, you need to generate a `val_set` which are data windows and labels that your model can accept. You can simply reuse the `windowed_dataset` function for that and you can pass in the `x_valid` points to generate the windows.

# %%
# Generate data windows of the validation set
val_set = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# You can then do the same training as before but pass in the `val_set` to the `validation_data` parameter of the `fit()` method.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
   tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Set the learning rate
learning_rate = 2e-6

# Set the optimizer 
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(dataset,epochs=100, validation_data=val_set)
# Out:
# 2024-05-02 09:09:34.534283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:34.536059: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:34.537673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:34.710915: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:34.769238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:34.770997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:34.772561: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:35.008588: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:35.010496: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:35.011808: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:35.173011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# Epoch 1/100
# 2024-05-02 09:09:35.224623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:35.226695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:35.228336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:35.519402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:35.522373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:35.524334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:35.727475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:35.785742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:35.787270: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:35.788694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:36.017769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:36.020076: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:36.021610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:36.187838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:36.249537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:36.251902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:36.253389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:36.949433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:37.441084: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:37.823311: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:37.825518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:37.826882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:37.991277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:38.050941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:38.053049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:38.054582: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:38.281560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:38.283813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:38.285542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:38.463738: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:38.527309: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:38.529986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:38.531950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:39.130697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:39.947794: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
#      28/Unknown - 7s 18ms/step - loss: 27.1578 - mae: 27.6550
# 2024-05-02 09:09:42.499849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [461]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-02 09:09:42.500264: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [461]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-02 09:09:42.750321: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:42.752421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:42.753777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:42.926831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:42.986550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:42.988146: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:42.989831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:43.222212: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:43.224686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:43.225954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-02 09:09:43.393600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-02 09:09:43.454167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-02 09:09:43.455986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-02 09:09:43.458084: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 31/31 [==============================] - 9s 78ms/step - loss: 26.2604 - mae: 26.7573 - val_loss: 29.7290 - val_mae: 30.2288
# Epoch 2/100
# 31/31 [==============================] - 1s 21ms/step - loss: 12.7554 - mae: 13.2480 - val_loss: 29.9242 - val_mae: 30.4230
# Epoch 3/100
# 31/31 [==============================] - 1s 26ms/step - loss: 9.4444 - mae: 9.9316 - val_loss: 23.3702 - val_mae: 23.8680
# Epoch 4/100
# 31/31 [==============================] - 1s 20ms/step - loss: 7.6241 - mae: 8.1064 - val_loss: 18.2092 - val_mae: 18.7064
# Epoch 5/100
# 31/31 [==============================] - 1s 21ms/step - loss: 7.1078 - mae: 7.5905 - val_loss: 14.8049 - val_mae: 15.2960
# Epoch 6/100
# 31/31 [==============================] - 1s 21ms/step - loss: 6.8523 - mae: 7.3359 - val_loss: 15.4695 - val_mae: 15.9651
# Epoch 7/100
# 31/31 [==============================] - 1s 20ms/step - loss: 6.7448 - mae: 7.2292 - val_loss: 13.3556 - val_mae: 13.8504
# Epoch 8/100
# 31/31 [==============================] - 1s 21ms/step - loss: 6.5658 - mae: 7.0473 - val_loss: 13.6865 - val_mae: 14.1817
# Epoch 9/100
# 31/31 [==============================] - 1s 25ms/step - loss: 6.4149 - mae: 6.8932 - val_loss: 11.1909 - val_mae: 11.6818
# Epoch 10/100
# 31/31 [==============================] - 1s 21ms/step - loss: 6.2665 - mae: 6.7467 - val_loss: 12.5136 - val_mae: 13.0050
# Epoch 11/100
# 31/31 [==============================] - 1s 27ms/step - loss: 6.1075 - mae: 6.5907 - val_loss: 11.2346 - val_mae: 11.7249
# Epoch 12/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.9785 - mae: 6.4586 - val_loss: 10.9953 - val_mae: 11.4862
# Epoch 13/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.9469 - mae: 6.4306 - val_loss: 10.8995 - val_mae: 11.3912
# Epoch 14/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.8123 - mae: 6.2924 - val_loss: 10.2779 - val_mae: 10.7668
# Epoch 15/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.7559 - mae: 6.2373 - val_loss: 9.8153 - val_mae: 10.3044
# Epoch 16/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.7776 - mae: 6.2599 - val_loss: 10.8000 - val_mae: 11.2936
# Epoch 17/100
# 31/31 [==============================] - 1s 24ms/step - loss: 5.6539 - mae: 6.1312 - val_loss: 10.6799 - val_mae: 11.1726
# Epoch 18/100
# 31/31 [==============================] - 1s 25ms/step - loss: 5.6594 - mae: 6.1396 - val_loss: 9.0360 - val_mae: 9.5181
# Epoch 19/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.4750 - mae: 5.9585 - val_loss: 8.4947 - val_mae: 8.9825
# Epoch 20/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.3946 - mae: 5.8777 - val_loss: 8.8217 - val_mae: 9.3044
# Epoch 21/100
# 31/31 [==============================] - 1s 25ms/step - loss: 5.3998 - mae: 5.8778 - val_loss: 8.8036 - val_mae: 9.2885
# Epoch 22/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.3490 - mae: 5.8293 - val_loss: 8.0002 - val_mae: 8.4889
# Epoch 23/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.2608 - mae: 5.7389 - val_loss: 8.5825 - val_mae: 9.0683
# Epoch 24/100
# 31/31 [==============================] - 1s 24ms/step - loss: 5.2252 - mae: 5.7070 - val_loss: 8.0232 - val_mae: 8.5056
# Epoch 25/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.2399 - mae: 5.7208 - val_loss: 8.1844 - val_mae: 8.6687
# Epoch 26/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.2163 - mae: 5.6926 - val_loss: 8.1172 - val_mae: 8.6018
# Epoch 27/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.1325 - mae: 5.6130 - val_loss: 8.8634 - val_mae: 9.3492
# Epoch 28/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.1059 - mae: 5.5807 - val_loss: 9.4754 - val_mae: 9.9674
# Epoch 29/100
# 31/31 [==============================] - 1s 24ms/step - loss: 5.1338 - mae: 5.6084 - val_loss: 7.8660 - val_mae: 8.3505
# Epoch 30/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.0641 - mae: 5.5464 - val_loss: 7.8825 - val_mae: 8.3662
# Epoch 31/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.0237 - mae: 5.5012 - val_loss: 7.3338 - val_mae: 7.8162
# Epoch 32/100
# 31/31 [==============================] - 1s 25ms/step - loss: 5.0277 - mae: 5.5055 - val_loss: 7.1987 - val_mae: 7.6829
# Epoch 33/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9911 - mae: 5.4669 - val_loss: 7.8972 - val_mae: 8.3802
# Epoch 34/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9379 - mae: 5.4150 - val_loss: 7.1530 - val_mae: 7.6382
# Epoch 35/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9290 - mae: 5.4041 - val_loss: 8.7461 - val_mae: 9.2349
# Epoch 36/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.0244 - mae: 5.5021 - val_loss: 7.1768 - val_mae: 7.6607
# Epoch 37/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.8821 - mae: 5.3573 - val_loss: 6.7828 - val_mae: 7.2673
# Epoch 38/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.9440 - mae: 5.4242 - val_loss: 6.7465 - val_mae: 7.2305
# Epoch 39/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.9040 - mae: 5.3793 - val_loss: 7.0787 - val_mae: 7.5601
# Epoch 40/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.8858 - mae: 5.3632 - val_loss: 7.7938 - val_mae: 8.2785
# Epoch 41/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.9930 - mae: 5.4700 - val_loss: 7.3199 - val_mae: 7.8011
# Epoch 42/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.8288 - mae: 5.3058 - val_loss: 7.3341 - val_mae: 7.8161
# Epoch 43/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.8364 - mae: 5.3110 - val_loss: 6.4549 - val_mae: 6.9356
# Epoch 44/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.8591 - mae: 5.3388 - val_loss: 7.8008 - val_mae: 8.2878
# Epoch 45/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.8057 - mae: 5.2813 - val_loss: 7.1234 - val_mae: 7.6040
# Epoch 46/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.8244 - mae: 5.3025 - val_loss: 7.5958 - val_mae: 8.0804
# Epoch 47/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7868 - mae: 5.2594 - val_loss: 7.4973 - val_mae: 7.9810
# Epoch 48/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.0283 - mae: 5.5074 - val_loss: 7.3667 - val_mae: 7.8487
# Epoch 49/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.8224 - mae: 5.3029 - val_loss: 6.5772 - val_mae: 7.0622
# Epoch 50/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7247 - mae: 5.2013 - val_loss: 7.1369 - val_mae: 7.6171
# Epoch 51/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.7359 - mae: 5.2150 - val_loss: 6.5332 - val_mae: 7.0159
# Epoch 52/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7271 - mae: 5.2012 - val_loss: 7.0824 - val_mae: 7.5623
# Epoch 53/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7333 - mae: 5.2117 - val_loss: 6.6240 - val_mae: 7.1033
# Epoch 54/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7064 - mae: 5.1833 - val_loss: 6.6443 - val_mae: 7.1239
# Epoch 55/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6933 - mae: 5.1699 - val_loss: 7.3342 - val_mae: 7.8190
# Epoch 56/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.7049 - mae: 5.1801 - val_loss: 7.0725 - val_mae: 7.5524
# Epoch 57/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6702 - mae: 5.1447 - val_loss: 7.1291 - val_mae: 7.6111
# Epoch 58/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.8156 - mae: 5.2960 - val_loss: 7.4946 - val_mae: 7.9826
# Epoch 59/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.7838 - mae: 5.2573 - val_loss: 6.4100 - val_mae: 6.8916
# Epoch 60/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.6108 - mae: 5.0867 - val_loss: 6.5825 - val_mae: 7.0623
# Epoch 61/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.6335 - mae: 5.1077 - val_loss: 6.8029 - val_mae: 7.2829
# Epoch 62/100
# 31/31 [==============================] - 1s 22ms/step - loss: 4.6639 - mae: 5.1389 - val_loss: 6.4384 - val_mae: 6.9183
# Epoch 63/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5931 - mae: 5.0731 - val_loss: 6.1783 - val_mae: 6.6588
# Epoch 64/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7275 - mae: 5.2052 - val_loss: 6.0013 - val_mae: 6.4845
# Epoch 65/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6332 - mae: 5.1046 - val_loss: 6.0211 - val_mae: 6.5050
# Epoch 66/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5975 - mae: 5.0742 - val_loss: 7.2892 - val_mae: 7.7736
# Epoch 67/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6011 - mae: 5.0800 - val_loss: 6.0693 - val_mae: 6.5503
# Epoch 68/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5736 - mae: 5.0514 - val_loss: 6.2321 - val_mae: 6.7125
# Epoch 69/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.5559 - mae: 5.0335 - val_loss: 6.9117 - val_mae: 7.3947
# Epoch 70/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6588 - mae: 5.1373 - val_loss: 6.4531 - val_mae: 6.9336
# Epoch 71/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.5928 - mae: 5.0711 - val_loss: 5.7521 - val_mae: 6.2310
# Epoch 72/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6450 - mae: 5.1196 - val_loss: 6.5439 - val_mae: 7.0275
# Epoch 73/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6639 - mae: 5.1392 - val_loss: 6.5618 - val_mae: 7.0453
# Epoch 74/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.7004 - mae: 5.1766 - val_loss: 5.6801 - val_mae: 6.1596
# Epoch 75/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.7588 - mae: 5.2329 - val_loss: 5.6862 - val_mae: 6.1654
# Epoch 76/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6006 - mae: 5.0773 - val_loss: 6.3958 - val_mae: 6.8750
# Epoch 77/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6524 - mae: 5.1295 - val_loss: 5.7569 - val_mae: 6.2386
# Epoch 78/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5349 - mae: 5.0103 - val_loss: 6.0390 - val_mae: 6.5154
# Epoch 79/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.5383 - mae: 5.0097 - val_loss: 6.2421 - val_mae: 6.7197
# Epoch 80/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5813 - mae: 5.0613 - val_loss: 5.5271 - val_mae: 6.0020
# Epoch 81/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.5460 - mae: 5.0261 - val_loss: 6.3416 - val_mae: 6.8225
# Epoch 82/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.5091 - mae: 4.9859 - val_loss: 5.5775 - val_mae: 6.0540
# Epoch 83/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6252 - mae: 5.0994 - val_loss: 5.9729 - val_mae: 6.4509
# Epoch 84/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6612 - mae: 5.1392 - val_loss: 5.4972 - val_mae: 5.9758
# Epoch 85/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6387 - mae: 5.1151 - val_loss: 5.8763 - val_mae: 6.3565
# Epoch 86/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5431 - mae: 5.0218 - val_loss: 6.2666 - val_mae: 6.7463
# Epoch 87/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5925 - mae: 5.0693 - val_loss: 5.5957 - val_mae: 6.0777
# Epoch 88/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.5700 - mae: 5.0460 - val_loss: 5.6826 - val_mae: 6.1694
# Epoch 89/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5096 - mae: 4.9871 - val_loss: 5.8325 - val_mae: 6.3107
# Epoch 90/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5373 - mae: 5.0109 - val_loss: 6.1757 - val_mae: 6.6523
# Epoch 91/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.4956 - mae: 4.9729 - val_loss: 6.1360 - val_mae: 6.6107
# Epoch 92/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.5579 - mae: 5.0320 - val_loss: 6.0946 - val_mae: 6.5686
# Epoch 93/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.4862 - mae: 4.9599 - val_loss: 5.4517 - val_mae: 5.9257
# Epoch 94/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.7410 - mae: 5.2158 - val_loss: 6.2967 - val_mae: 6.7769
# Epoch 95/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5168 - mae: 4.9911 - val_loss: 5.5858 - val_mae: 6.0728
# Epoch 96/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.4721 - mae: 4.9475 - val_loss: 5.6251 - val_mae: 6.1120
# Epoch 97/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.4702 - mae: 4.9468 - val_loss: 5.3707 - val_mae: 5.8458
# Epoch 98/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5059 - mae: 4.9767 - val_loss: 5.3224 - val_mae: 5.7987
# Epoch 99/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.6392 - mae: 5.1174 - val_loss: 5.3566 - val_mae: 5.8342
# Epoch 100/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.5597 - mae: 5.0366 - val_loss: 6.0029 - val_mae: 6.4795
